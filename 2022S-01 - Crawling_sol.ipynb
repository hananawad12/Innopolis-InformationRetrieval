# %% [markdown]
# # 1. Crawler
#
# ## 1.0. Related example
#
# This code shows `wget`-like tool written in python. Run it from console (`python wget.py`), make it work. Check the code, reuse, and modify for your needs.

# %%
import argparse
import os
import re
import requests


def wget(url, filename):
    # allow redirects - in case file is relocated
    resp = requests.get(url, allow_redirects=True)
    # this can also be 2xx, but for simplicity now we stick to 200
    # you can also check for `resp.ok`
    if resp.status_code != 200:
        print(resp.status_code, resp.reason, 'for', url)
        return
    
    # just to be cool and print something
    print(*[f"{key}: {value}" for key, value in resp.headers.items()], sep='\n')
    print()
    
    # try to extract filename from url
    if filename is None:
        # start with http*, ends if ? or # appears (or none of)
        m = re.search("^http.*/([^/\?#]*)[\?#]?", url)
        filename = m.group(1)
        if not filename:
            raise NameError(f"Filename neither given, nor found for {url}")

    # what will you do in case 2 websites store file with the same name?
    if os.path.exists(filename):
        raise OSError(f"File {filename} already exists")
    
    with open(filename, 'wb') as f:
        f.write(resp.content)
        print(f"File saved as {filename}")


if __name__ == "__main__":
    parser = argparse.ArgumentParser(description='download file.')
    parser.add_argument("-O", type=str, default=None, dest='filename', help="output file name. Default -- taken from resource")
    parser.add_argument("url", type=str, default=None, help="Provide URL here")
    args = parser.parse_args()
    wget(args.url, args.filename)

# %% [markdown]
# ### 1.0.1. How to parse a page?
#
# If you build a crawler, you might follow one of the approaches:
# 1. search for URLs in the page, assuming this is just a text.
# 2. search for URLs in the places where URLs should appear: `<a href=..`, `<img src=...`, `<iframe src=...` and so on.
#
# To follow the first approach you can rely on some good regular expression. [Like this](https://stackoverflow.com/a/3809435).
#
# To follow the second approach just read one of these: [short answer](https://stackoverflow.com/questions/1080411/retrieve-links-from-web-page-using-python-and-beautifulsoup) or [exhaustive explanation](https://hackersandslackers.com/scraping-urls-with-beautifulsoup/).

# %% [markdown]
# ## 1.1. [15] Download and persist #
# Please complete a code for `load()`, `download()` and `persist()` methods of `Document` class. What they do:
# - for a given URL `download()` method downloads binary data and stores in `self.content`. It returns `True` for success, else `False`.
# - `persist()` method saves `self.content` somewhere in file system. We do it to avoid multiple downloads (for caching in other words).
# - `load()` method loads data from hard drive. Returns `True` for success.
#
# Tests checks that your code somehow works.
#
# **NB Passing the test doesn't mean you correctly completed the task.** These are **criteria, which have to be fullfilled**:
# 1. URL is a unique identifier (as it is a subset of URI). Thus, documents with different URLs should be stored in different files. Typical errors: documents from the same domain are overwritten to the same file, URLs with similar endings are downloaded to the same file, etc.
# 2. The document can be not only a text file, but also a binary. Pay attention that if you download `mp3` file, it still can be played. Hint: don't hurry to convert everything to text.

# %%
import requests
from urllib.parse import quote
class Document:
    
    def __init__(self, url):
        self.url = url
        self.filename=None
        self.content=[]
        
    def get(self):
        if not self.load():
            if not self.download():
                raise FileNotFoundError(self.url)
            else:
                self.persist()
                
                
    
    def download(self):
        #TODO download self.url content, store it in self.content and return True in case of success
        self.content= requests.get(self.url).content
        if self.content:
            return True
        else:
            return False
    
    def persist(self):
        self.filename=quote(self.url).replace("/","_")+(self.url[-4:] if self.url[-4:] in ('.pdf', '.mp3', '.avi', '.mp4', '.txt') else '.txt')
        with open(self.filename, 'wb') as f:
            f.write(self.content)
            #print("file is written")
            
    def load(self):
        #TODO load content from hard drive, store it in self.content and return True in case of success
        if self.filename!=None:
            with open(self.filename, 'rb') as f:
               for line in f:
                   self.content+=line
        
               return True
        else:
            #print("filename is not exists")
            return False

# %% [markdown]
# ### 1.1.1. Tests ###

# %%
doc = Document('http://sprotasov.ru/data/iu.txt')

doc.get()
assert doc.content, "Document download failed"
assert "Code snippets, demos and labs for the course" in str(doc.content), "Document content error"

doc.get()
assert doc.load(), "Load should return true for saved document"
assert "Code snippets, demos and labs for the course" in str(doc.content), "Document load from disk error"

# %% [markdown]
# ## 1.2. [M][15] Account the caching policy
#
# Sometimes remote documents (especially when we speak about static content like `js` or `gif`) can swear that they will not change for some time. This is done by setting [Cache-Control response header](https://developer.mozilla.org/en-US/docs/Web/HTTP/Headers/Cache-Control).

# %%
import requests
requests.get('https://polyfill.io/v3/polyfill.min.js').headers['Cache-Control']
# Out:
# 'public, s-maxage=31536000, max-age=604800, stale-while-revalidate=604800, stale-if-error=604800'

# %% [markdown]
# Please study the documentation and implement a descendant to a `Document` class, which will refresh the document in case of expired cache even if the file is already on the hard drive.

# %%
import requests
import os
import time


class CachedDocument(Document):
    #currenttime-downloadtime<maxage--->load
    def __init__(self,url):
        Document.__init__(self,url)
        self.filename=quote(self.url).replace("/","_")+(self.url[-4:] if self.url[-4:] in ('.pdf', '.mp3', '.avi', '.mp4', '.txt') else '.txt')
        
    def get(self):
        r=requests.get(self.url).headers['Cache-Control']
        max_age=int(r.split(',')[2].split('=')[1])
        if not os.path.exists('./'+self.filename):
            print("page is downloaded")
            self.download()
            self.persist()
            
        else:
            download_time=round(os.stat('./'+self.filename).st_mtime)
            current_time=round(time.time())
            dur=current_time-download_time
            print('dur: ',dur)
            print('max age: ',max_age)
            if dur>max_age:
                print("page is refresed")
                self.download()
                self.persist()
            else:
                if self.load():
                    print('page is loaded ')

# %% [markdown]
# ### 1.2.1. Tests
#
# Add logging in your code and show that your code behaves differently for documents with different caching policy.

# %%
doc = CachedDocument('https://polyfill.io/v3/polyfill.min.js')
doc.get()
time.sleep(2)
doc.get()
time.sleep(2)
doc.get()

doc = CachedDocument('https://yandex.ru/')
doc.get()
time.sleep(2)
doc.get()
time.sleep(2)
doc.get()
# Out:
# dur:  10296
# max age:  604800
# page is loaded
# dur:  10298
# max age:  604800
# page is loaded
# dur:  10301
# max age:  604800
# page is loaded
# dur:  8673
# max age:  0
# page is refresed
# dur:  3
# max age:  0
# page is refresed
# dur:  2
# max age:  0
# page is refresed

# %% [markdown]
# ## 1.3. [10] Parse HTML ##
# `BeautifulSoap` library is a de facto standard to parse XML and HTML documents in python. Use it to complete `parse()` method that extracts document contents. You should initialize:
# - `self.anchors` list of tuples `('text', 'url')` met in a document. Be aware, there exist relative links (e.g. `../content/pic.jpg`). Use `urllib.parse.urljoin()` to fix this issue.
# - `self.images` list of images met in a document. Again, links can be relative to current page.
# - `self.text` should keep plain text of the document without scripts, tags, comments and so on. You can refer to [this stackoverflow answer](https://stackoverflow.com/a/1983219) for details.
#
# **NB All these 3 criteria must be fulfilled to get full point for the task.**

# %%
from bs4 import BeautifulSoup
from bs4.element import Comment
from urllib.parse import urljoin


class HtmlDocument(Document):
    def tag_visible(self,element):
        if element.parent.name in ['style', 'script', 'head', 'title', 'meta', '[document]']:
            return False
        if isinstance(element, Comment):
            return False
        return True
      
    def text_from_html(self,body):
        soup = BeautifulSoup(body, 'html.parser')
        texts = soup.findAll(text=True)
        visible_texts = filter(self.tag_visible, texts)
        return u" ".join(t.strip() for t in visible_texts)
    
    def parse(self):
        #TODO extract plain text, images and links from the document
        #self.anchors = [("fake link text", "http://fake.url/")]
        #self.images = ["http://image.com/fake.jpg"]
        #self.text = "fake text and some other text"
        self.anchors = []
        self.images = []
        self.text=None
        body = requests.get(self.url).text
        soup = BeautifulSoup(body, "html.parser") 
        links=soup.find_all('a')
        images=soup.find_all('img')
            
          
        for a in links:
            text=a.get_text().replace("\n", "").replace("\r", "")
            link=a.get('href')
            link=urljoin(self.url,link)
            self.anchors.append((text,link))

        for img in images:
            source=img.get('src')
            source=urljoin(self.url,source)
            self.images.append(source)
           
        
        
        self.text=self.text_from_html(body)
        #print("==========================anchors============================")   
        #print(self.anchors)
        #print("==========================images==============================")
        #print(self.images)
        #print("===========================text================================")
        #print(self.text)

# %%
### 1.3.1. Tests

# %%
doc = HtmlDocument("http://sprotasov.ru")
doc.get()
doc.parse()

assert "just few links" in doc.text, "Error parsing text"
assert "http://sprotasov.ru/images/gb.svg" in doc.images, "Error parsing images"
assert any(p[1] == "https://twitter.com/07C3" for p in doc.anchors), "Error parsing links"

# %% [markdown]
# ## 1.4. [10] Document analysis ##
# Complete the code for `HtmlDocumentTextData` class. Implement word and sentence splitting (use any method you can propose).
#
# **Criteria of success**:
# 1. Your `get_word_stats()` method should return `Counter` object.
# 2. Don't forget to lowercase your words for counting.
# 3. Sentences should be obtained inside `<body>` tag only.

# %%
from collections import Counter

class HtmlDocumentTextData(HtmlDocument):
    def __init__(self, url):
        self.url=url
        self.doc = HtmlDocument(url)
    
    def get_sentences(self):
        #TODO implement sentence parser
        result = []
        
        body = requests.get(self.url).text
        result=self.text_from_html(body)      
        return result
    
    def get_word_stats(self):
        #TODO return Counter object of the document, containing mapping {`word` -> count_in_doc}
        try:
            words=self.get_sentences()
            tokens=words.split()
            tokens = [ele for ele in tokens if ele.strip()]
            res={}
            for word in tokens:
                word=word.lower()
                if len(word)>3:
                    if word in res.keys():
                        res[word]+=1
                    else:
                        res[word]=1

            return Counter(res)
        except:
            pass

# %% [markdown]
# ### 1.4.1. Tests ###

# %%
doc = HtmlDocumentTextData("https://innopolis.university/")
print(doc.get_word_stats().most_common(10))
assert [x for x in doc.get_word_stats().most_common(10) if x[0] == 'иннополис'], 'иннополис should be among most common'
# Out:
# [('иннополис', 19), ('университет', 12), ('области', 10), ('лаборатория', 10), ('университета', 9), ('центр', 9), ('разработки', 7), ('2022', 7), ('образовательной', 6), ('технологий', 6)]

# %% [markdown]
# ## 1.5. [M][35] Languages
# Maybe you heard, that there are multiple languages in the world. European languages, like Russian and English, use similar puctuation, but even in this family there is ¡Spanish!
#
# Other languages can use different punctiation rules, like **Arabic or [Thai](http://www.thai-language.com/ref/breaking-words)**.
#
# Your task is to support (at least) three languages (English, Arabic, and Thai) tokenization in your `HtmlDocumentTextData` class descendant.
#
# What should you do:
# 1. Use any language dection techniques, e.g. [langdetect](https://pypi.org/project/langdetect/).
# 2. Use language-specific tokenization tools, e.g. for [Thai](https://pythainlp.github.io/tutorials/notebooks/pythainlp_get_started.html#Tokenization-and-Segmentation) and [Arabic](https://github.com/CAMeL-Lab/camel_tools).
# 3. Use these pages to test your code: [1](https://www.bangkokair.com/tha/baggage-allowance) and [2](https://alfajr-news.net/details/%D9%85%D8%B4%D8%B1%D9%88%D8%B9-%D8%AF%D9%8A%D9%85%D9%88%D9%82%D8%B1%D8%A7%D8%B7%D9%8A-%D9%81%D9%8A-%D8%A7%D9%84%D9%83%D9%88%D9%86%D8%BA%D8%B1%D8%B3-%D8%A7%D9%84%D8%A3%D9%85%D8%B1%D9%8A%D9%83%D9%8A-%D9%84%D9%85%D8%B9%D8%A7%D9%82%D8%A8%D8%A9-%D8%A8%D9%88%D8%AA%D9%8A%D9%86).

# %%
# !pip install langdetect
# !pip install spacy
# !pip install pythainlp
# Out:
# Requirement already satisfied: langdetect in c:\users\hanan\anaconda3\lib\site-packages (1.0.7)
# Requirement already satisfied: six in c:\users\hanan\anaconda3\lib\site-packages (from langdetect) (1.15.0)
# Requirement already satisfied: spacy in c:\users\hanan\anaconda3\lib\site-packages (3.2.1)
# Requirement already satisfied: pathy>=0.3.5 in c:\users\hanan\anaconda3\lib\site-packages (from spacy) (0.6.1)
# Requirement already satisfied: spacy-loggers<2.0.0,>=1.0.0 in c:\users\hanan\anaconda3\lib\site-packages (from spacy) (1.0.1)
# Requirement already satisfied: blis<0.8.0,>=0.4.0 in c:\users\hanan\anaconda3\lib\site-packages (from spacy) (0.7.5)
# Requirement already satisfied: requests<3.0.0,>=2.13.0 in c:\users\hanan\anaconda3\lib\site-packages (from spacy) (2.25.1)
# Requirement already satisfied: thinc<8.1.0,>=8.0.12 in c:\users\hanan\anaconda3\lib\site-packages (from spacy) (8.0.13)
# Requirement already satisfied: tqdm<5.0.0,>=4.38.0 in c:\users\hanan\anaconda3\lib\site-packages (from spacy) (4.59.0)
# Requirement already satisfied: srsly<3.0.0,>=2.4.1 in c:\users\hanan\anaconda3\lib\site-packages (from spacy) (2.4.2)
# Requirement already satisfied: langcodes<4.0.0,>=3.2.0 in c:\users\hanan\anaconda3\lib\site-packages (from spacy) (3.3.0)
# Requirement already satisfied: catalogue<2.1.0,>=2.0.6 in c:\users\hanan\anaconda3\lib\site-packages (from spacy) (2.0.6)
# Requirement already satisfied: spacy-legacy<3.1.0,>=3.0.8 in c:\users\hanan\anaconda3\lib\site-packages (from spacy) (3.0.8)
# Requirement already satisfied: jinja2 in c:\users\hanan\anaconda3\lib\site-packages (from spacy) (2.11.3)
# Requirement already satisfied: pydantic!=1.8,!=1.8.1,<1.9.0,>=1.7.4 in c:\users\hanan\anaconda3\lib\site-packages (from spacy) (1.8.2)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in c:\users\hanan\anaconda3\lib\site-packages (from spacy) (1.0.6)
# Requirement already satisfied: wasabi<1.1.0,>=0.8.1 in c:\users\hanan\anaconda3\lib\site-packages (from spacy) (0.9.0)
# Requirement already satisfied: packaging>=20.0 in c:\users\hanan\anaconda3\lib\site-packages (from spacy) (20.9)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in c:\users\hanan\anaconda3\lib\site-packages (from spacy) (2.0.6)
# Requirement already satisfied: numpy>=1.15.0 in c:\users\hanan\anaconda3\lib\site-packages (from spacy) (1.20.1)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in c:\users\hanan\anaconda3\lib\site-packages (from spacy) (3.0.6)
# Requirement already satisfied: setuptools in c:\users\hanan\anaconda3\lib\site-packages (from spacy) (60.8.1)
# Requirement already satisfied: typer<0.5.0,>=0.3.0 in c:\users\hanan\anaconda3\lib\site-packages (from spacy) (0.4.0)
# Requirement already satisfied: pyparsing>=2.0.2 in c:\users\hanan\anaconda3\lib\site-packages (from packaging>=20.0->spacy) (2.4.7)
# Requirement already satisfied: smart-open<6.0.0,>=5.0.0 in c:\users\hanan\anaconda3\lib\site-packages (from pathy>=0.3.5->spacy) (5.2.1)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in c:\users\hanan\anaconda3\lib\site-packages (from pydantic!=1.8,!=1.8.1,<1.9.0,>=1.7.4->spacy) (3.7.4.3)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\hanan\anaconda3\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy) (2020.12.5)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\users\hanan\anaconda3\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy) (1.26.4)
# Requirement already satisfied: chardet<5,>=3.0.2 in c:\users\hanan\anaconda3\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy) (4.0.0)
# Requirement already satisfied: idna<3,>=2.5 in c:\users\hanan\anaconda3\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy) (2.10)
# Requirement already satisfied: click<9.0.0,>=7.1.1 in c:\users\hanan\anaconda3\lib\site-packages (from typer<0.5.0,>=0.3.0->spacy) (7.1.2)
# Requirement already satisfied: MarkupSafe>=0.23 in c:\users\hanan\anaconda3\lib\site-packages (from jinja2->spacy) (1.1.1)
# Requirement already satisfied: pythainlp in c:\users\hanan\anaconda3\lib\site-packages (3.0.0)
# Requirement already satisfied: requests>=2.22.0 in c:\users\hanan\anaconda3\lib\site-packages (from pythainlp) (2.25.1)
# Requirement already satisfied: tinydb>=3.0 in c:\users\hanan\anaconda3\lib\site-packages (from pythainlp) (4.6.1)
# Requirement already satisfied: chardet<5,>=3.0.2 in c:\users\hanan\anaconda3\lib\site-packages (from requests>=2.22.0->pythainlp) (4.0.0)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\hanan\anaconda3\lib\site-packages (from requests>=2.22.0->pythainlp) (2020.12.5)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\users\hanan\anaconda3\lib\site-packages (from requests>=2.22.0->pythainlp) (1.26.4)
# Requirement already satisfied: idna<3,>=2.5 in c:\users\hanan\anaconda3\lib\site-packages (from requests>=2.22.0->pythainlp) (2.10)

# %%
#requirements
#install langdetect,spacy, pythainlp
from langdetect import detect
import spacy
from spacy.lang.en import English
from spacy.lang.ar import Arabic
from spacy.lang.th import Thai
class MultilingualHtmlDocumentTextData(HtmlDocumentTextData):
    
    #TODO your code here
    def get_word_stats(self):
        #TODO return Counter object of the document, containing mapping {`word` -> count_in_doc}
        words=self.get_sentences()
        lang=detect(words)
        #nlp = spacy.load("en_core_web_sm")
        print(lang)
        if lang=='en':
            nlp=English()
            words = nlp(words)
            tokens = [token.text for token in words]
            tokens = [ele for ele in tokens if ele.strip()]
        elif lang=='ar':
            nlp=Arabic()
            words = nlp(words)
            tokens = [token.text for token in words]
            tokens = [ele for ele in tokens if ele.strip()]
        elif lang=='th':
            nlp=Thai()
            words = nlp(words)
            tokens = [token.text for token in words]
            tokens = [ele for ele in tokens if ele.strip()]

        else:
            tokens=words.split()
            tokens = [ele for ele in tokens if ele.strip()]

        res={}
        for word in tokens:
            if len(word)>3:
                word=word.lower()
                if word in res.keys():
                    res[word]+=1
                else:
                    res[word]=1
        return Counter(res)

# %% [markdown]
# ### 1.5.1. Tests

# %%
doc = MultilingualHtmlDocumentTextData("https://www.bangkokair.com/tha/baggage-allowance")
print(doc.get_word_stats().most_common(10))

doc = MultilingualHtmlDocumentTextData("https://alfajr-news.net/details/%D9%85%D8%B4%D8%B1%D9%88%D8%B9-%D8%AF%D9%8A%D9%85%D9%88%D9%82%D8%B1%D8%A7%D8%B7%D9%8A-%D9%81%D9%8A-%D8%A7%D9%84%D9%83%D9%88%D9%86%D8%BA%D8%B1%D8%B3-%D8%A7%D9%84%D8%A3%D9%85%D8%B1%D9%8A%D9%83%D9%8A-%D9%84%D9%85%D8%B9%D8%A7%D9%82")
print(doc.get_word_stats().most_common(10))
# Out:
# th
# [('สัมภาระ', 34), ('กิโลกรัม', 21), ('เดินทาง', 17), ('เที่ยวบิน', 16), ('บริการ', 16), ('ข้อมูล', 13), ('น้ำหนัก', 13), ('เกี่ยวกับ', 11), ('พิเศษ', 11), ('ผู้โดยสาร', 10)]
# ar
# [('تعليق', 12), ('مشاهده', 10), ('الإمارات', 6), ('الفجر', 4), ('حملة', 3), ('أخبار', 3), ('أغسطس', 3), ('2020', 3), ('javascript', 2), ('your', 2)]

# %%
#Just for testing the BFS 
graph = {
  'A' : ['B','C'],
  'B' : ['D', 'E'],
  'C' : ['F'],
  'D' : [],
  'E' : ['F'],
  'F' : []
}

visited = []  
queue = []     

def visited_nodes(visited,queue,level):
    try:
        while queue:
            s=queue.pop(0)
            level+=1
            print(s)  
            for neighbour in graph[s[0]]:
                if neighbour not in visited:
                    visited.append(neighbour)
                    queue.append([neighbour,level])
    except:
        visited_nodes(visited,queue,level)
    return visited

def bfs(visited, graph, node):
    level=0
    visited.append(node)
    queue.append([node,level])
    return visited_nodes(visited,queue,level)



print(bfs(visited, graph, 'A'))
# Out:
# ['A', 0]
# ['B', 1]
# ['C', 1]
# ['D', 2]
# ['E', 2]
# ['F', 3]
# ['A', 'B', 'C', 'D', 'E', 'F']

# %% [markdown]
# ## 1.5. [15] Crawling ##
#
# Method `crawl_generator()` is given starting url (`source`) and max depth of search. It should return a **generator** of `HtmlDocumentTextData` objects (return a document as soon as it is downloaded and parsed). You can benefit from `yield obj_name` python construction. Use `HtmlDocumentTextData.anchors` field to go deeper.

# %%
from queue import Queue

class Crawler:
    
    def crawl_generator(self, source, depth=1):
        #TODO return real crawling results. Don't forget to process failures
        graph={}
        visited = [] 
        queue = []     
        def links(source):
            try:
                lst=[]
                d=HtmlDocumentTextData(source)
                d.parse()
                links=d.anchors
                for lnk in links:
                    lst.append(lnk[1])
                return list(dict.fromkeys(lst))
            except:
                pass
            
            return []
        
        def sub_links(source,depth):
            lst=[]
            lnks=[]
            i=0
            if depth>=1:
                lst=links(source)
                graph[source]=lst
                lnks.append(lst)
                depth-=1
                while depth!=0:
                    sub_lnks=[]
                    for item in lnks[i]:
                        lst=links(item)
                        graph[item]=lst
                        if len(lst)!=0:
                            for l in lst:
                                sub_lnks.append(l)
                            
                    if len(sub_lnks)!=0:
                        lnks.append(sub_lnks)
                    i+=1  
                    depth-=1            
            else:
                graph[source]=[]
                
            return graph
        
        graph=sub_links(source,depth)
        def visited_nodes(visited,queue,level):
            try:
                while queue:
                    s=queue.pop(0)
                    level+=1
                    #print(s)  
                    for neighbour in graph[s[0]]:
                        if neighbour not in visited:
                            visited.append(neighbour)
                            queue.append([neighbour,level])
            except:
                visited_nodes(visited,queue,level)
            return visited
        
        def bfs(visited, graph, node):
            level=0
            visited.append(node)
            queue.append([node,level])
            return visited_nodes(visited,queue,level)


        sources=bfs(visited, graph, source)
        for source in sources:
            yield HtmlDocumentTextData(source)

# %% [markdown]
# ### 1.5. Tests ###

# %%
crawler = Crawler()
counter = Counter()

for c in crawler.crawl_generator("https://innopolis.university/en/", 2):
    print(c.doc.url)
    if c.doc.url[-4:] in ('.pdf', '.mp3', '.avi', '.mp4', '.txt'):
        print("Skipping", c.doc.url)
        continue
    counter.update(c.get_word_stats())
    print(len(counter), "distinct word(s) so far")
    
print("Done")

print(counter.most_common(20))
assert [x for x in counter.most_common(20) if x[0] == 'innopolis'], 'innopolis should be among most common'
# Out:
# https://innopolis.university/en/
# 303 distinct word(s) so far
# https://apply.innopolis.university/en
# 1152 distinct word(s) so far
# https://corporate.innopolis.university/en
# 1327 distinct word(s) so far
# https://media.innopolis.university/en
# 1386 distinct word(s) so far
# https://innopolis.university/lk/
# 1732 distinct word(s) so far
# https://innopolis.university/en/about/
# 1867 distinct word(s) so far
# https://innopolis.university/en/board/
# 1958 distinct word(s) so far
# https://innopolis.university/en/team/
# 1960 distinct word(s) so far
# https://innopolis.university/en/team-structure/
# 1963 distinct word(s) so far
# https://innopolis.university/en/team-structure/education-academics/
# 1966 distinct word(s) so far
# https://innopolis.university/en/team-structure/techcenters/
# 1968 distinct word(s) so far
# https://innopolis.university/en/faculty/
# 3111 distinct word(s) so far
# https://career.innopolis.university/en/job/
# 3723 distinct word(s) so far
# https://career.innopolis.university/en/
# 4049 distinct word(s) so far
# https://innopolis.university/en/campus
# 4188 distinct word(s) so far
# https://innopolis.university/en/contacts/
# 4198 distinct word(s) so far
# https://apply.innopolis.university/en/
# 4198 distinct word(s) so far
# https://apply.innopolis.university/en/bachelor/
# 4291 distinct word(s) so far
# https://apply.innopolis.university/en/bachelor/CE/
# 4311 distinct word(s) so far
# https://apply.innopolis.university/en/bachelor/DS-AI/
# 4337 distinct word(s) so far
# https://apply.innopolis.university/en/master/
# 4370 distinct word(s) so far
# https://apply.innopolis.university/en/master/datascience/
# 4475 distinct word(s) so far
# https://apply.innopolis.university/en/master/securityandnetworkengineering/
# 4532 distinct word(s) so far
# https://apply.innopolis.university/en/master/development/
# 4596 distinct word(s) so far
# https://apply.innopolis.university/en/master/robotics/
# 4672 distinct word(s) so far
# https://apply.innopolis.university/en/master/technological-entrepreneurship/
# 4889 distinct word(s) so far
# https://apply.innopolis.university/en/postgraduate-study/
# 4978 distinct word(s) so far
# https://apply.innopolis.university/en/stud-life/
# 5060 distinct word(s) so far
# https://innopolis.university/en/international-relations-office/
# 5390 distinct word(s) so far
# https://innopolis.university/en/incomingstudents/
# 5444 distinct word(s) so far
# https://innopolis.university/en/outgoingstudents/
# 5481 distinct word(s) so far
# https://innopolis.university/en/teachingexcellencecenter/
# 5734 distinct word(s) so far
# https://innopolis.university/en/writinghubhome/
# 5752 distinct word(s) so far
# https://alumni.innopolis.university/
# 6026 distinct word(s) so far
# https://innopolis.university/en/research/
# 6062 distinct word(s) so far
# https://innopolis.university/en/lab-operating-systems/
# 6096 distinct word(s) so far
# https://innopolis.university/en/lab-software-service-engineering/
# 6195 distinct word(s) so far
# https://innopolis.university/en/lab-industrializing-software/
# 6239 distinct word(s) so far
# https://innopolis.university/en/lab-bioinformatics/
# 6282 distinct word(s) so far
# https://innopolis.university/en/lab-game-development/
# 6339 distinct word(s) so far
# https://innopolis.university/en/lab-oil-gas/
# 6385 distinct word(s) so far
# https://innopolis.university/en/mlkr/
# 6544 distinct word(s) so far
# https://innopolis.university/en/lab-cyberphysical-systems/
# 6584 distinct word(s) so far
# https://innopolis.university/en/lab-networks-blockchain/
# 6637 distinct word(s) so far
# https://innopolis.university/en/lab-robotics/
# 6735 distinct word(s) so far
# https://innopolis.university/en/proekty/activity/
# 6774 distinct word(s) so far
# https://innopolis.university/en/proekty/podderzhka-innovacionnoj-deyatelnosti/
# 6821 distinct word(s) so far
# https://innopolis.university/en/startupstudio/
# 6855 distinct word(s) so far
# https://innopolis.university/en/internationalpartners/
# 6859 distinct word(s) so far
# https://innopolis.university/en/organizatsiya-i-provedenie-meropriyatiy/
# 7006 distinct word(s) so far
# https://innopolis.university/en/?special=Y
# 7015 distinct word(s) so far
# https://innopolis.university/search/
# 7018 distinct word(s) so far
# https://innopolis.university/
# 7188 distinct word(s) so far
# https://innopolis.university/en/ido/
# 7214 distinct word(s) so far
# https://dovuz.innopolis.university/
# 7567 distinct word(s) so far
# https://university.innopolis.ru/en/about/
# 7567 distinct word(s) so far
# http://www.campuslife.innopolis.ru
# 7667 distinct word(s) so far
# https://media.innopolis.university/news/clobal-ai-challenge/
# 7819 distinct word(s) so far
# https://media.innopolis.university/news/webinar-interstudents-eng/
# 7843 distinct word(s) so far
# https://media.innopolis.university/news/devops-summer-school/
# 7977 distinct word(s) so far
# https://media.innopolis.university/news/webinar-for-international-candidates-/
# 7984 distinct word(s) so far
# https://media.innopolis.university/news/registration-innopolis-open-2020/
# 8084 distinct word(s) so far
# https://media.innopolis.university/news/cyber-resilience-petrenko/
# 8256 distinct word(s) so far
# https://media.innopolis.university/news/innopolis-university-extends-international-application-deadline-/
# 8269 distinct word(s) so far
# https://media.innopolis.university/en/
# 8269 distinct word(s) so far
# https://www.facebook.com/InnopolisU
# 8269 distinct word(s) so far
# https://vk.com/innopolisu
# 8480 distinct word(s) so far
# https://www.youtube.com/user/InnopolisU
# 8491 distinct word(s) so far
# https://www.instagram.com/innopolisu/
# 8491 distinct word(s) so far
# https://apply.innopolis.ru/en/index.php
# 8763 distinct word(s) so far
# https://university.innopolis.ru/en/cooperation/
# 8765 distinct word(s) so far
# https://panoroo.com/virtual-tours/NvQZM6B2
# 8766 distinct word(s) so far
# https://media.innopolis.university/en/news/
# 8766 distinct word(s) so far
# https://media.innopolis.university/en/events/
# 8768 distinct word(s) so far
# http://www.minsvyaz.ru/en/
# 8843 distinct word(s) so far
# http://минобрнауки.рф/
# 8843 distinct word(s) so far
# https://innopolis.university/public/files/Consent_to_the_processing_of_PD_for_UI.pdf
# Skipping https://innopolis.university/public/files/Consent_to_the_processing_of_PD_for_UI.pdf
# https://apply.innopolis.university/en/?special=Y
# 8843 distinct word(s) so far
# https://apply.innopolis.university/search/
# 8848 distinct word(s) so far
# https://apply.innopolis.university/
# 8848 distinct word(s) so far
# https://apply.innopolis.ru/en/get-in/
# 9082 distinct word(s) so far
# https://apply.innopolis.university/en/faq/
# 9093 distinct word(s) so far
# https://apply.innopolis.university/en/#block5327
# 9093 distinct word(s) so far
# https://apply.innopolis.university/en/olympiad-bonus/
# 9155 distinct word(s) so far
# https://apply.innopolis.university/en/development2/
# 9158 distinct word(s) so far
# https://apply.innopolis.university/en/razrabotka-bezopasnyh-sistem-i-setej/
# 9158 distinct word(s) so far
# https://www.ets.org/s/cv/toefl/at-home/
# 9158 distinct word(s) so far
# https://englishtest.duolingo.com/
# 9158 distinct word(s) so far
# http://nic.gov.ru/en/proc/nic/legalize
# 9306 distinct word(s) so far
# https://www.hcch.net/en/instruments/conventions/authorities1/?cid=41
# 9387 distinct word(s) so far
# https://drive.google.com/file/d/10spw7SYKomHSyWuaNMWMl3-t_OiiR-qg/view
# 9387 distinct word(s) so far
# https://drive.google.com/file/d/193kK6kV0RAzdp_wRksSJy9a9y1s0gMaE/view
# 9387 distinct word(s) so far
# https://drive.google.com/file/d/1YYhSiVTm6bxxeBt0fv7rbrMdgU0C2e2_/view
# 9387 distinct word(s) so far
# https://drive.google.com/file/d/1HATau9H2J2rJbC45o2EiREsGDKpNODA1/view
# 9387 distinct word(s) so far
# https://innopolis.university/sveden/apply/
# 9631 distinct word(s) so far
# https://www.embassy-worldwide.com/country/russia/?__cf_chl_jschl_tk__=a94cd95afa1311b39144c68ade05bb4c404c36e0-1603284143-0-AdT5wLmOm0W3vCpGYOe8JBgEGI_UYrAl9mWAr7wF22c8uVpnkbbSHOvIwBv5Iye4w3P-miBYqs-aStGmVo93k7jYCS4NQJ4cBWodhvlIsetlsYyQkaTTq_1OvbDiIsbarbVcfHyi_KH0wJDIB4Z1JSPevDKQ6oR5rH2pop3jbhEktZbCT0kRVDrWxej3fichPVhNcCSMyJo5Z_HfpLkGjswRihnDmrFYGShrU_nM8GeNxsvd1lq4tor0CCi4CDY-BmwRNtNskMF1TZM7sHN7KiYYjvEUqpo8sdK-5_o9tJQx
# 9848 distinct word(s) so far
# https://apply.innopolis.ru/get-in/tests/
# 10167 distinct word(s) so far
# https://innopolis.university/en/campus/
# 10167 distinct word(s) so far
# https://innopolis.com/en/
# 10320 distinct word(s) so far
# mailto:admissions@innopolis.ru
# 10320 distinct word(s) so far
# https://apply.innopolis.university/public/files/Consent_to_the_processing_of_PD_for_UI.pdf
# Skipping https://apply.innopolis.university/public/files/Consent_to_the_processing_of_PD_for_UI.pdf
# http://www.campuslife.innopolis.ru/main
# 10320 distinct word(s) so far
# https://corporate.innopolis.university/en/outsourcingrd/
# 10339 distinct word(s) so far
# https://corporate.innopolis.university/en/technologicalaudit/
# 10427 distinct word(s) so far
# https://corporate.innopolis.university/en/stratsession/
# 10531 distinct word(s) so far
# https://corporate.innopolis.university/en/Bootcamp/
# 10609 distinct word(s) so far
# https://corporate.innopolis.university/en/education/
# 10620 distinct word(s) so far
# https://corporate.innopolis.university/
# 10811 distinct word(s) so far
# https://corporate.innopolis.university/public/files/Consent_to_the_processing_of_PD_for_UI.pdf
# Skipping https://corporate.innopolis.university/public/files/Consent_to_the_processing_of_PD_for_UI.pdf
# https://media.innopolis.university/en/events
# 10811 distinct word(s) so far
# https://media.innopolis.university/
# 10851 distinct word(s) so far
# https://media.innopolis.university/en?TAGS=*
# 10851 distinct word(s) so far
# https://media.innopolis.university/en?TAGS=Industry
# 10911 distinct word(s) so far
# https://media.innopolis.university/en?TAGS=Research
# 10961 distinct word(s) so far
# https://media.innopolis.university/en?TAGS=Education
# 11014 distinct word(s) so far
# https://media.innopolis.university/en?TAGS=Students life
# 11062 distinct word(s) so far
# https://media.innopolis.university/en?TAGS=Global
# 11089 distinct word(s) so far
# https://media.innopolis.university/en?TAGS=Robotics
# 11089 distinct word(s) so far
# https://media.innopolis.university/en?TAGS=Blockchain
# 11089 distinct word(s) so far
# https://media.innopolis.university/en?TAGS=Cybersecurity
# 11089 distinct word(s) so far
# https://media.innopolis.university/en/news/webinar-interstudents-eng/
# 11093 distinct word(s) so far
# https://media.innopolis.university/en/news/devops-summer-school/
# 11125 distinct word(s) so far
# https://media.innopolis.university/en/news/webinar-for-international-candidates-/
# 11125 distinct word(s) so far
# https://media.innopolis.university/en/news/registration-innopolis-open-2020/
# 11135 distinct word(s) so far
# https://media.innopolis.university/en/news/cyber-resilience-petrenko/
# 11177 distinct word(s) so far
# https://media.innopolis.university/en/news/innopolis-university-extends-international-application-deadline-/
# 11177 distinct word(s) so far
# https://media.innopolis.university/en/news/self-driven-school/
# 11200 distinct word(s) so far
# https://media.innopolis.university/en/news/webinar-for-international-candidates/
# 11209 distinct word(s) so far
# https://media.innopolis.university/en/news/the-first-release-for-testers-in-innopolis-university/
# 11266 distinct word(s) so far
# https://media.innopolis.university/en/?PAGEN_2=2
# 11276 distinct word(s) so far
# https://media.innopolis.university/en/?PAGEN_2=3
# 11287 distinct word(s) so far
# https://media.innopolis.university/en/?PAGEN_2=38
# 11353 distinct word(s) so far
# https://media.innopolis.university/en/?PAGEN_2=39
# 11379 distinct word(s) so far
# https://spec.innopolis.university/
# 11443 distinct word(s) so far
# https://www.youtube.com/channel/UCZNo9zTHZNZOW4fSFcCKh_A
# 11443 distinct word(s) so far
# https://media.innopolis.university/public/files/Consent_to_the_processing_of_PD_for_UI.pdf
# Skipping https://media.innopolis.university/public/files/Consent_to_the_processing_of_PD_for_UI.pdf
# https://innopolis.university/about/
# 11668 distinct word(s) so far
# https://innopolis.university/board/
# 11783 distinct word(s) so far
# https://innopolis.university/team/
# 11784 distinct word(s) so far
# https://innopolis.university/team-structure/
# 11790 distinct word(s) so far
# https://innopolis.university/team-structure/education-academics/
# 11795 distinct word(s) so far
# https://innopolis.university/team-structure/techcenters/
# 11797 distinct word(s) so far
# https://innopolis.university/faculty/
# 13089 distinct word(s) so far
# https://career.innopolis.university
# 13652 distinct word(s) so far
# https://career.innopolis.university/corporate-life/
# 13718 distinct word(s) so far
# https://career.innopolis.university/relocation/
# 14049 distinct word(s) so far
# https://career.innopolis.university/job
# 17453 distinct word(s) so far
# https://innopolis.university/campus
# 17634 distinct word(s) so far
# https://innopolis.university/sveden/
# 17634 distinct word(s) so far
# http://iustore.innopolis.ru
# 17728 distinct word(s) so far
# https://apply.innopolis.university/open-day/
# 17771 distinct word(s) so far
# https://apply.innopolis.university/grant/
# 17876 distinct word(s) so far
# https://apply.innopolis.university/olympiad-bonus/
# 17944 distinct word(s) so far
# https://apply.innopolis.university/faq/
# 18092 distinct word(s) so far
# https://dovuz.innopolis.university/about/
# 18148 distinct word(s) so far
# https://dovuz.innopolis.university/ege
# 18278 distinct word(s) so far
# https://dovuz.innopolis.university/training/
# 18381 distinct word(s) so far
# https://dovuz.innopolis.university/olympics/
# 18461 distinct word(s) so far
# https://dovuz.innopolis.university/events/
# 18461 distinct word(s) so far
# http://progmatica.ru/?utm_source=site&utm_medium=main_ui
# 18588 distinct word(s) so far
# https://apply.innopolis.university/bachelor/
# 18734 distinct word(s) so far
# https://apply.innopolis.university/bachelor/DS-AI/
# 18775 distinct word(s) so far
# https://apply.innopolis.university/bachelor/CE/
# 18792 distinct word(s) so far
# https://apply.innopolis.university/master/
# 18834 distinct word(s) so far
# https://apply.innopolis.university/master/datascience/
# 18920 distinct word(s) so far
# https://apply.innopolis.university/master/securityandnetworkengineering/
# 19001 distinct word(s) so far
# https://apply.innopolis.university/master/robotics/
# 19088 distinct word(s) so far
# https://apply.innopolis.university/master/technological-entrepreneurship/
# 19434 distinct word(s) so far
# https://apply.innopolis.university/master/development/
# 19479 distinct word(s) so far
# https://apply.innopolis.university/postgraduate-study/
# 19526 distinct word(s) so far
# https://innopolis.university/dpo-courses/
# 19574 distinct word(s) so far
# https://corporate.innopolis.university/program-catalog/it-likbez-dlya-hr/
# 19611 distinct word(s) so far
# https://corporate.innopolis.university/education/
# 19739 distinct word(s) so far
# https://edu.innopolis.university/ooc
# 20349 distinct word(s) so far
# https://stc.innopolis.university/
# 20389 distinct word(s) so far
# https://innopolis.university/ooc/
# 21101 distinct word(s) so far
# https://innopolis.university/ido/
# 21183 distinct word(s) so far
# https://innopolis.university/ppcenter/
# 21303 distinct word(s) so far
# https://apply.innopolis.university/stazhirovki-i-trudoustrojstvo/
# 21548 distinct word(s) so far
# https://apply.innopolis.university/stud-life/
# 21706 distinct word(s) so far
# https://innopolis.university/research/
# 21737 distinct word(s) so far
# https://innopolis.university/team-structure/team-faculty/
# 21747 distinct word(s) so far
# https://innopolis.university/lab-operating-systems/
# 21812 distinct word(s) so far
# https://innopolis.university/lab-software-service-engineering/
# 21889 distinct word(s) so far
# https://innopolis.university/lab-industrializing-software/
# 21931 distinct word(s) so far
# https://innopolis.university/lab-bioinformatics/
# 21957 distinct word(s) so far
# https://innopolis.university/lab-oil-gas/
# 22012 distinct word(s) so far
# https://innopolis.university/lab-game-development/
# 22081 distinct word(s) so far
# https://innopolis.university/mlkr/
# 22170 distinct word(s) so far
# https://innopolis.university/lab-cyberphysical-systems/
# 22206 distinct word(s) so far
# https://innopolis.university/lab-networks-blockchain/
# 22262 distinct word(s) so far
# https://innopolis.university/lab-robotics/
# 22413 distinct word(s) so far
# https://innopolis.university/publikatsii
# 22443 distinct word(s) so far
# https://innopolis.university/technologytransfercenter
# 22643 distinct word(s) so far
# https://innopolis.university/seminars/
# 22680 distinct word(s) so far
# https://innopolis.university/proekty/activity/
# 22737 distinct word(s) so far
# https://innopolis.university/portfel-proektov/
# 23022 distinct word(s) so far
# https://ai.innopolis.university/
# 23071 distinct word(s) so far
# https://innopolis.university/center-blockchain/
# 23221 distinct word(s) so far
# https://innopolis.university/centergis/
# 23534 distinct word(s) so far
# https://innopolis.university/center-cybersecurity/
# 23768 distinct word(s) so far
# https://innopolis.university/center-oil/
# 23887 distinct word(s) so far
# https://innopolis.university/center-robotics/
# 24375 distinct word(s) so far
# https://innopolis.university/proekty/podderzhka-innovacionnoj-deyatelnosti/
# 24410 distinct word(s) so far
# https://innopolis.university/digital-economy
# 24526 distinct word(s) so far
# https://innopolis.university/startupstudio/
# 24830 distinct word(s) so far
# https://innopolis.university/organizatsiya-i-provedenie-meropriyatiy/
# 25010 distinct word(s) so far
# https://innopolis.university/sponsorship/
# 25043 distinct word(s) so far
# https://innopolis.university/contacts/
# 25046 distinct word(s) so far
# https://innopolis.university/lk/?special=Y
# 25046 distinct word(s) so far
# https://innopolis.university/en/lk/
# 25047 distinct word(s) so far
# https://mail.innopolis.ru/
# 25063 distinct word(s) so far
# https://portal.university.innopolis.ru
# 25064 distinct word(s) so far
# https://it.university.innopolis.ru/portal
# 25087 distinct word(s) so far
# https://apply.innopolis.ru/get-in/
# 25087 distinct word(s) so far
# https://my.university.innopolis.ru/
# 25090 distinct word(s) so far
# https://dovuz.innopolis.university/login/
# 25112 distinct word(s) so far
# mailto:it@innopolis.ru
# 25112 distinct word(s) so far
# https://innopolis.university/public/files/Согласие на обработку ПДн для УИ.pdf
# Skipping https://innopolis.university/public/files/Согласие на обработку ПДн для УИ.pdf
# https://innopolis.university/en/about/?special=Y
# 25112 distinct word(s) so far
# https://corporate.innopolis.university/en/
# 25112 distinct word(s) so far
# https://robotics.innopolis.university/en/
# 25121 distinct word(s) so far
# https://innopolis.university/upload/iblock/c68/AR_2016.pdf
# Skipping https://innopolis.university/upload/iblock/c68/AR_2016.pdf
# https://innopolis.university/upload/iblock/26c/AR_2017.pdf
# Skipping https://innopolis.university/upload/iblock/26c/AR_2017.pdf
# https://innopolis.university/upload/iblock/59f/AR_2018.pdf
# Skipping https://innopolis.university/upload/iblock/59f/AR_2018.pdf
# https://innopolis.university/upload/iblock/0b2/AR_2019.pdf
# Skipping https://innopolis.university/upload/iblock/0b2/AR_2019.pdf
# https://innopolis.university/upload/iblock/189/AR2020(3).pdf
# Skipping https://innopolis.university/upload/iblock/189/AR2020(3).pdf
# https://innopolis.university/en/board/?special=Y
# 25121 distinct word(s) so far
# https://digital.gov.ru/ru/
# 25327 distinct word(s) so far
# mailto:office@digital.gov.ru
# 25327 distinct word(s) so far
# http://mzio.tatarstan.ru
# 25497 distinct word(s) so far
# mailto:mzio@tatar.ru
# 25497 distinct word(s) so far
# https://innopolis.university/en/team/?special=Y
# 25497 distinct word(s) so far
# https://innopolis.university/en/team-structure/?special=Y
# 25497 distinct word(s) so far
# https://innopolis.university/en/team-director/
# 25516 distinct word(s) so far
# https://innopolis.university/en/team-rector/
# 25523 distinct word(s) so far
# https://innopolis.university/en/team-structure/education-academics/?special=Y
# 25523 distinct word(s) so far
# https://innopolis.university/en/team-structure/team-faculty/
# 25533 distinct word(s) so far
# https://innopolis.university/en/team-structure/team-faculty2/
# 25546 distinct word(s) so far
# https://innopolis.university/en/team-academicpolicy/
# 25562 distinct word(s) so far
# https://innopolis.university/en/team-structure/techcenters/?special=Y
# 25562 distinct word(s) so far
# https://innopolis.university/en/center-robotics/
# 25608 distinct word(s) so far
# https://innopolis.university/en/center-cybersecurity/
# 25668 distinct word(s) so far
# https://innopolis.university/en/centergis/
# 25701 distinct word(s) so far
# https://innopolis.university/en/center-blockchain/
# 25736 distinct word(s) so far
# https://innopolis.university/en/centerforartificialintelligence/
# 25756 distinct word(s) so far
# https://innopolis.university/en/center-oil/
# 25767 distinct word(s) so far
# https://innopolis.university/en/faculty/?special=Y
# 25767 distinct word(s) so far
# https://innopolis.university/en/professor/giancarlo-succi-/
# 25767 distinct word(s) so far
# https://innopolis.university/en/professor/manuel-mazzara-/
# 25767 distinct word(s) so far
# https://innopolis.university/en/Labofsoftwareandserviceengineering/
# 25767 distinct word(s) so far
# https://innopolis.university/en/professor/vladimir-ivanov-/
# 25767 distinct word(s) so far
# https://innopolis.university/en/professor/andrey-sadovykh-/
# 25767 distinct word(s) so far
# https://innopolis.university/en/professor/eugene-zuev-/
# 25767 distinct word(s) so far
# https://innopolis.university/en/professor/nikolay-shilov-/
# 25767 distinct word(s) so far
# https://innopolis.university/en/professor/aleksander-klimchik-/
# 25767 distinct word(s) so far
# https://innopolis.university/en/professor/igor-gaponov-/
# 25767 distinct word(s) so far
# https://innopolis.university/en/professor/mohammad-reza-bahrami-/
# 25767 distinct word(s) so far
# https://innopolis.university/en/professor/artem-burmyakov-/
# 25767 distinct word(s) so far
# https://innopolis.university/en/professor/adil-khan-/
# 25767 distinct word(s) so far
# https://innopolis.university/en/professor/sergey-gorodetskiy-/
# 25767 distinct word(s) so far
# https://innopolis.university/en/professor/joseph-brown-/
# 25767 distinct word(s) so far
# https://innopolis.university/en/professor/yaroslav-kholodov-/
# 25767 distinct word(s) so far
# https://innopolis.university/en/professor/rabab-marouf-/
# 25767 distinct word(s) so far
# https://innopolis.university/en/professor/shinnazar-seytnazarov/
# 25767 distinct word(s) so far
# https://innopolis.university/en/team-faculty/#block2653
# 25767 distinct word(s) so far
# https://innopolis.university/en/professor/mirko-farina-/
# 25767 distinct word(s) so far
# https://innopolis.university/en/professor/artur-karimov-/
# 25767 distinct word(s) so far
# https://innopolis.university/en/professor/alena-protasova-/
# 25767 distinct word(s) so far
# https://innopolis.university/en/professor/ruslan-saduov-/
# 25767 distinct word(s) so far
# https://innopolis.university/en/professor/sergey-kladko-/
# 25767 distinct word(s) so far
# https://innopolis.university/en/professor/kirill-polyetkin-/
# 25767 distinct word(s) so far
# https://innopolis.university/en/professor/guzel-fazlyeva-/
# 25767 distinct word(s) so far
# https://innopolis.university/en/professor/sergey-savin-/
# 25777 distinct word(s) so far
# http://www.researchgate.net/profile/Sergei_Savin2
# 26483 distinct word(s) so far
# http://orcid.org/0000-0001-7954-3144
# 26483 distinct word(s) so far
# http://www.scopus.com/authid/detail.uri?authorId=55978984900
# 26491 distinct word(s) so far
# http://scholar.google.ru/citations?user=sVjTfqEAAAAJ&hl=en
# 26577 distinct word(s) so far
# https://innopolis.university/en/center-robotics
# 26577 distinct word(s) so far
# https://innopolis.university/en/professor/stanislav-protasov-/
# 26577 distinct word(s) so far
# https://innopolis.university/en/professor/artem-kruglov-/
# 26577 distinct word(s) so far
# https://innopolis.university/en/professor/georgiy-gelvanovskiy-/
# 26577 distinct word(s) so far
# https://innopolis.university/en/professor/ivan-konyukhov-/
# 26577 distinct word(s) so far
# https://innopolis.university/en/professor/hein-roelfsema-/
# 26577 distinct word(s) so far
# https://innopolis.university/en/professor/paolo-ciancarini-/
# 26577 distinct word(s) so far
# https://innopolis.university/en/professor/bertrand-meyer-/
# 26577 distinct word(s) so far
# https://innopolis.university/en/professor/leon-derczynski-/
# 26577 distinct word(s) so far
# https://innopolis.university/en/professor/sebastian-denef-/
# 26577 distinct word(s) so far
# https://innopolis.university/en/professor/mohamad-kassab-/
# 26577 distinct word(s) so far
# https://innopolis.university/en/professor/tatyana-samsonova-/
# 26577 distinct word(s) so far
# https://career.innopolis.university/corporate-life
# 26577 distinct word(s) so far
# https://career.innopolis.university/relocation
# 26577 distinct word(s) so far
# https://career.innopolis.university/job/
# 26577 distinct word(s) so far
# https://carrer.innopolis.university
# 26577 distinct word(s) so far
# https://career.innopolis.university/en/job/?section_id=*
# 26577 distinct word(s) so far
# https://career.innopolis.university/en/job/?section_id=22891
# 26577 distinct word(s) so far
# https://hh.ru/vacancy/50499917
# 26578 distinct word(s) so far
# https://career.innopolis.university/en/job/#career-feedback__form
# 26578 distinct word(s) so far
# mailto:faculty@innopolis.ru
# 26578 distinct word(s) so far
# https://career.innopolis.university/public/files/career_personal_data.docx
# 26950 distinct word(s) so far
# https://career.innopolis.university/en/corporate-life/
# 26968 distinct word(s) so far
# https://career.innopolis.university/en/relocation/
# 27078 distinct word(s) so far
# https://career.innopolis.university/public/files/Consent_to_the_processing_of_PD_for_UI.pdf
# Skipping https://career.innopolis.university/public/files/Consent_to_the_processing_of_PD_for_UI.pdf
# https://career.innopolis.university/
# 27078 distinct word(s) so far
# https://career.innopolis.university/success-stories/julia-kazaeva/
# 27094 distinct word(s) so far
# https://career.innopolis.university/success-stories/farid-gainullin/
# 27094 distinct word(s) so far
# https://career.innopolis.university/success-stories/salimzhan-gafurov-en/
# 27094 distinct word(s) so far
# mailto:resume@innopolis.ru
# 27094 distinct word(s) so far
# https://innopolis.university/en/campus?special=Y
# 27094 distinct word(s) so far
# http://hotel.innopolis.university/
# 27208 distinct word(s) so far
# https://innopolis.university/en/contacts/?special=Y
# 27208 distinct word(s) so far
# mailto:university@innopolis.ru
# 27208 distinct word(s) so far
# mailto:pr@innopolis.ru
# 27208 distinct word(s) so far
# tel:+78432039253
# 27208 distinct word(s) so far
# mailto:corporate@innopolis.university
# 27208 distinct word(s) so far
# mailto:dovuz@innopolis.university
# 27208 distinct word(s) so far
# https://apply.innopolis.university/en/bachelor/?special=Y
# 27208 distinct word(s) so far
# https://apply.innopolis.university/en/bachelor/null
# 27208 distinct word(s) so far
# https://innopolis.university/filespublic/2020MathTestEng.pdf
# Skipping https://innopolis.university/filespublic/2020MathTestEng.pdf
# https://innopolis.university/filespublic/Computer%20science.pdf
# Skipping https://innopolis.university/filespublic/Computer%20science.pdf
# https://innopolis.university/filespublic/English.pdf
# Skipping https://innopolis.university/filespublic/English.pdf
# https://innopolis.university/filespublic/contest-26104-en.pdf
# Skipping https://innopolis.university/filespublic/contest-26104-en.pdf
# https://innopolis.university/filespublic/Overview%20of%20the%20BS%20Program1.pdf
# Skipping https://innopolis.university/filespublic/Overview%20of%20the%20BS%20Program1.pdf
# https://apply.innopolis.ru/en/get-in/tests/
# 27208 distinct word(s) so far
# https://apply.innopolis.university/en/bachelor/CE/?special=Y
# 27208 distinct word(s) so far
# https://apply.innopolis.university/en/bachelor/DS-AI/?special=Y
# 27208 distinct word(s) so far
# https://apply.innopolis.university/en/master/?special=Y
# 27208 distinct word(s) so far
# https://apply.innopolis.university/en/grant/
# 27232 distinct word(s) so far
# https://apply.innopolis.university/en/master/datascience/?special=Y
# 27232 distinct word(s) so far
# https://innopolis.university/filespublic/DSAI_2021_ENG_.pdf
# Skipping https://innopolis.university/filespublic/DSAI_2021_ENG_.pdf
# https://innopolis.university/files/Master%60s%20program%20Data%20Analysis%20and%20Artificial%20Intelligence.pdf
# Skipping https://innopolis.university/files/Master%60s%20program%20Data%20Analysis%20and%20Artificial%20Intelligence.pdf
# https://apply.innopolis.university/en/master/securityandnetworkengineering/?special=Y
# 27232 distinct word(s) so far
# https://innopolis.university/filespublic/MS%20SNE_2021.pdf
# Skipping https://innopolis.university/filespublic/MS%20SNE_2021.pdf
# https://innopolis.university/files/Master%60s%20program%20Security%20and%20Network%20Engineering.pdf
# Skipping https://innopolis.university/files/Master%60s%20program%20Security%20and%20Network%20Engineering.pdf
# https://apply.innopolis.university/en/master/development/?special=Y
# 27232 distinct word(s) so far
# https://apply.innopolis.university/en/master/development/#block5931
# 27232 distinct word(s) so far
# https://innopolis.university/files/Master%60s%20program%20Software%20Engineering.pdf
# Skipping https://innopolis.university/files/Master%60s%20program%20Software%20Engineering.pdf
# https://apps.apple.com/ru/app/id1447056625
# 27498 distinct word(s) so far
# https://apps.apple.com/ru/app/id1138728895
# 27584 distinct word(s) so far
# https://kazanfirst.ru/news/534089
# 27679 distinct word(s) so far
# https://profit.kz/news/37024/Opredelilis-pobediteli-nFactorial-Challenge/
# 27783 distinct word(s) so far
# https://apply.innopolis.university/en/master/robotics/?special=Y
# 27783 distinct word(s) so far
# https://innopolis.university/filespublic/IU%20MS%20Robotics%20Presentation_2021.pdf
# Skipping https://innopolis.university/filespublic/IU%20MS%20Robotics%20Presentation_2021.pdf
# https://innopolis.university/files/Master%60s%20program%20Robotics%20and%20Computer%20Vision.pdf
# Skipping https://innopolis.university/files/Master%60s%20program%20Robotics%20and%20Computer%20Vision.pdf
# https://apply.innopolis.university/en/master/technological-entrepreneurship/?special=Y
# 27783 distinct word(s) so far
# https://innopolis.university/filespublic/photo_2021-12-07_17-00-50.jpg
# 28641 distinct word(s) so far
# https://minobrnauki.gov.ru/press-center/news/?ELEMENT_ID=25900
# 29159 distinct word(s) so far
# https://innopolis.university/files/Master%60s%20program%20Technological%20Entrepreneurship.pdf
# Skipping https://innopolis.university/files/Master%60s%20program%20Technological%20Entrepreneurship.pdf
# http://startupfairy.ru
# 29462 distinct word(s) so far
# https://startupfairy.ru/idea
# 29782 distinct word(s) so far
# https://startupfairy.ru/market
# 29937 distinct word(s) so far
# https://sputnik.systems/
# 29937 distinct word(s) so far
# http://www.shtrafy-gibdd.ru
# 30171 distinct word(s) so far
# https://www.indeed.com/
# 30195 distinct word(s) so far
# https://node.university/
# 30198 distinct word(s) so far
# https://www.rusonyx.ru/
# 30198 distinct word(s) so far
# https://apply.innopolis.university/en/postgraduate-study/?special=Y
# 30198 distinct word(s) so far
# https://apply.innopolis.university/en/stud-life/?special=Y
# 30198 distinct word(s) so far
# http://www.campuslife.innopolis.ru/events
# 30329 distinct word(s) so far
# http://www.campuslife.innopolis.ru/clubs
# 30378 distinct word(s) so far
# http://www.campuslife.innopolis.ru/innopoints
# 30404 distinct word(s) so far
# https://innopolis.university/en/international-relations-office
# 30404 distinct word(s) so far
# http://innopolis.ru/
# 30486 distinct word(s) so far
# https://innopolis.university/en/international-relations-office/?special=Y
# 30486 distinct word(s) so far
# https://innopolis.university/international-relations-office/
# 30486 distinct word(s) so far
# mailto:international@innopolis.university
# 30486 distinct word(s) so far
# https://innopolis.university/success-stories/abdelrahman-abounegm/
# 30486 distinct word(s) so far
# https://innopolis.university/success-stories/ananga-thapaliya/
# 30486 distinct word(s) so far
# https://innopolis.university/success-stories/kerim-kochekov/
# 30486 distinct word(s) so far
# https://innopolis.university/success-stories/maksim-korsunov/
# 30486 distinct word(s) so far
# https://innopolis.university/success-stories/marina-ivanova/
# 30486 distinct word(s) so far
# https://innopolis.university/success-stories/semen-kiselev/
# 30486 distinct word(s) so far
# https://innopolis.university/en/incomingstudents/?special=Y
# 30486 distinct word(s) so far
# https://innopolis.university/incomingstudents/
# 30486 distinct word(s) so far
# https://innopolis.university/en/incomingstudents/#block5171
# 30486 distinct word(s) so far
# https://innopolis.university/en/outgoingstudents/?special=Y
# 30486 distinct word(s) so far
# https://innopolis.university/outgoingstudents/
# 30486 distinct word(s) so far
# https://innopolis.university/en/teachingexcellencecenter/?special=Y
# 30486 distinct word(s) so far
# https://innopolis.university/teachingexcellencecenter/
# 30486 distinct word(s) so far
# https://innopolis.university/en/#block1133
# 30486 distinct word(s) so far
# https://innopolis.university/en/teachingexcellencecenter/fortas/
# 30560 distinct word(s) so far
# https://innopolis.university/en/teachingexcellencecenter/forfaculty/
# 30560 distinct word(s) so far
# https://innopolis.university/en/teachingexcellencecenter/trainings/
# 30614 distinct word(s) so far
# https://innopolis.university/en/teachingexcellencecenter/#block4504
# 30614 distinct word(s) so far
# https://www.iswnetwork.ca
# 30651 distinct word(s) so far
# mailto:o.zhirosh@innopolis.ru
# 30651 distinct word(s) so far
# https://innopolis.university/en/writinghubhome/?special=Y
# 30651 distinct word(s) so far
# https://innopolis.university/writinghubhome/
# 30651 distinct word(s) so far
# https://innopolis.university/en/writinghubhome/#block4697
# 30651 distinct word(s) so far
# https://innopolis.university/en/writinghubhome/whoweworkfor/
# 30654 distinct word(s) so far
# https://innopolis.university/en/writinghubhome/writinghubtutors/
# 30655 distinct word(s) so far
# https://innopolis.university/en/writinghubhome/signupforconsultation/
# 30666 distinct word(s) so far
# https://innopolis.university/en/writinghubhome/academicstylereminder/
# 30865 distinct word(s) so far
# https://innopolis.university/en/writinghubhome/writingtips2/
# 30877 distinct word(s) so far
# https://innopolis.university/en/writinghubhome/workshops2/
# 30935 distinct word(s) so far
# https://innopolis.university/en/writinghubhome/faq/
# 30941 distinct word(s) so far
# https://innopolis.university/en/writinghubhome/learn_more/
# 30949 distinct word(s) so far
# https://t.me/Inno_Uni_Writing_Hub
# 30956 distinct word(s) so far
# https://t.me/joinchat/Q48uDKMDGcTJN1EH
# 30957 distinct word(s) so far
# https://innopolis.university/en/writinghubhome/contactus/
# 30958 distinct word(s) so far
# https://alumni.innopolis.university/?special=Y
# 30958 distinct word(s) so far
# https://alumni.innopolis.university/en/
# 30958 distinct word(s) so far
# https://alumni.innopolis.university/registration/
# 30958 distinct word(s) so far
# https://alumni.innopolis.university/#block4478
# 30958 distinct word(s) so far
# https://alumni.innopolis.university/#block4481
# 30958 distinct word(s) so far
# https://kazanexpress.ru/
# 30961 distinct word(s) so far
# https://www.remyrobotics.com/
# 30961 distinct word(s) so far
# https://yorso.com/
# 31215 distinct word(s) so far
# mailto:#
# 31215 distinct word(s) so far
# https://alumni.innopolis.university/public/files/Consent_to_the_processing_of_PD_for_UI.pdf
# Skipping https://alumni.innopolis.university/public/files/Consent_to_the_processing_of_PD_for_UI.pdf
# https://www.facebook.com/innopolisU
# 31215 distinct word(s) so far
# https://alumni.innopolis.university/public/files/Согласие на обработку ПДн для УИ.pdf
# Skipping https://alumni.innopolis.university/public/files/Согласие на обработку ПДн для УИ.pdf
# https://innopolis.university/en/research/?special=Y
# 31215 distinct word(s) so far
# https://innopolis.university/en/research/null
# 31215 distinct word(s) so far
# https://innopolis.university/en/lab-operating-systems/?special=Y
# 31215 distinct word(s) so far
# mailto:e.zuev@innopolis.ru
# 31215 distinct word(s) so far
# https://innopolis.university/en/lab-software-service-engineering/?special=Y
# 31215 distinct word(s) so far
# mailto:n.shilov@innopolis.ru
# 31215 distinct word(s) so far
# https://innopolis.university/en/lab-industrializing-software/?special=Y
# 31215 distinct word(s) so far
# mailto:
# 31215 distinct word(s) so far
# https://innopolis.university/en/lab-bioinformatics/?special=Y
# 31215 distinct word(s) so far
# mailto:ya.kholodov@innopolis.ru
# 31215 distinct word(s) so far
# https://innopolis.university/en/lab-game-development/?special=Y
# 31215 distinct word(s) so far
# mailto:j.brown@innopolis.ru
# 31215 distinct word(s) so far
# https://innopolis.university/en/lab-oil-gas/?special=Y
# 31215 distinct word(s) so far
# https://innopolis.university/en/mlkr/?special=Y
# 31215 distinct word(s) so far
# https://doi.org/10.1007/s11760-018-1244-6
# 32146 distinct word(s) so far
# http://sprotasov.ru/cv/demo/scenes01/usa.html
# 32146 distinct word(s) so far
# https://www.mdpi.com/2072-4292/11/9/1136
# 32664 distinct word(s) so far
# https://ieeexplore.ieee.org/abstract/document/8441034
# 32679 distinct word(s) so far
# https://journals.plos.org/plosone/article?id=10.1371/journal.pone.0188996
# 33632 distinct word(s) so far
# https://arxiv.org/abs/2103.03589
# 33711 distinct word(s) so far
# https://www.researchgate.net/publication/348995619_An_approach_to_visual_thesaurus_exploration_a_case_study_for_Russian_language
# 34266 distinct word(s) so far
# http://sprotasov.ru/files/IPMT/map.html
# 100300 distinct word(s) so far
# https://github.com/IUCVLab/information-retrieval
# 100363 distinct word(s) so far
# https://github.com/hsu-ai-course/hsu.ai
# 100375 distinct word(s) so far
# https://github.com/IUCVLab/qp
# 100399 distinct word(s) so far
# mailto:a.khan@innopolis.ru
# 100399 distinct word(s) so far
# mailto:s.protasov@innopolis.ru
# 100399 distinct word(s) so far
# https://t.me/sprotasov
# 100400 distinct word(s) so far
# https://innopolis.university/en/lab-cyberphysical-systems/?special=Y
# 100400 distinct word(s) so far
# https://innopolis.university/en/lab-networks-blockchain/?special=Y
# 100400 distinct word(s) so far
# mailto:r.hussain@innopolis.ru
# 100400 distinct word(s) so far
# https://innopolis.university/en/lab-robotics/?special=Y
# 100400 distinct word(s) so far
# https://innopolis.university/en/proekty/activity/?special=Y
# 100400 distinct word(s) so far
# https://innopolis.university/en/proekty/activity/#2384
# 100400 distinct word(s) so far
# https://innopolis.university/digital-economy/
# 100400 distinct word(s) so far
# https://corporate.innopolis.university/outsourcingrd/
# 100415 distinct word(s) so far
# https://innopolis.university/en/proekty/podderzhka-innovacionnoj-deyatelnosti/?special=Y
# 100415 distinct word(s) so far
# https://innopolis.university/en/startupstudio/?special=Y
# 100415 distinct word(s) so far
# mailto:startupstudio@innopolis.ru
# 100415 distinct word(s) so far
# https://hightech.fm/2022/01/07/farmer-dating-startups-of-the-year
# 100708 distinct word(s) so far
# https://events.innopolis.university/startuphouse#rec340322840
# 100903 distinct word(s) so far
# https://innopolis.university/en/internationalpartners/?special=Y
# 100903 distinct word(s) so far
# https://innopolis.university/internationalpartners/
# 100903 distinct word(s) so far
# https://innopolis.university/en/organizatsiya-i-provedenie-meropriyatiy/?special=Y
# 100903 distinct word(s) so far
# https://innopolis.university/en/organizatsiya-i-provedenie-meropriyatiy/#block2342
# 100903 distinct word(s) so far
# https://media.innopolis.university/en/events/crossconf/
# 100903 distinct word(s) so far
# https://media.innopolis.university/en/events/mezhdunarodnyy-otraslevoy-khakaton-v-oblasti-iskusstvennogo-intellekta-the-global-ai-challenge-/
# 100903 distinct word(s) so far
# https://media.innopolis.university/en/events/olimpiada-innopolis-open-po-informatsionnoy-bezopasnosti/
# 100903 distinct word(s) so far
# https://media.innopolis.university/en/events/merge-2022/
# 100903 distinct word(s) so far
# https://media.innopolis.university/en/events/olimpiada-innopolis-open-po-informatike/
# 100903 distinct word(s) so far
# mailto:events@innopolis.ru
# 100903 distinct word(s) so far
# https://innopolis.university/search/?special=Y
# 100903 distinct word(s) so far
# https://innopolis.university/en/search/
# 100903 distinct word(s) so far
# https://innopolis.university/?special=Y
# 100903 distinct word(s) so far
# https://media.innopolis.university/news/vesennie-intensivy-iu-2022/
# 100926 distinct word(s) so far
# https://media.innopolis.university/news/courses-for-trainers-wro-2022/
# 100949 distinct word(s) so far
# https://media.innopolis.university/news/Obuchenie-dlya-tyutorov-edtech-2022/
# 100973 distinct word(s) so far
# https://media.innopolis.university/news/digital-transformation-universities/
# 101027 distinct word(s) so far
# https://media.innopolis.university/news/phantom-os-iu/
# 101158 distinct word(s) so far
# https://media.innopolis.university/news/innoride-iu/
# 101194 distinct word(s) so far
# https://media.innopolis.university/events/crossconf/
# 101238 distinct word(s) so far
# https://media.innopolis.university/events/mezhdunarodnyy-otraslevoy-khakaton-v-oblasti-iskusstvennogo-intellekta-the-global-ai-challenge-/
# 101248 distinct word(s) so far
# https://media.innopolis.university/events/olimpiada-innopolis-open-po-informatsionnoy-bezopasnosti/
# 101259 distinct word(s) so far
# https://media.innopolis.university/events/merge-2022/
# 101275 distinct word(s) so far
# https://media.innopolis.university/events/olimpiada-innopolis-open-po-informatike/
# 101277 distinct word(s) so far
# https://media.innopolis.university/events/
# 101279 distinct word(s) so far
# https://corporate.innopolis.university
# 101279 distinct word(s) so far
# http://www.innopolis.com/city/how-to-get/
# 101353 distinct word(s) so far
# tel:+7 (937) 586-43-17
# 101353 distinct word(s) so far
# https://minobrnauki.gov.ru
# 101416 distinct word(s) so far
# https://innopolis.university/files/politicacookies.pdf
# Skipping https://innopolis.university/files/politicacookies.pdf
# https://www.minobrnauki.gov.ru/action/situational_center/
# 101436 distinct word(s) so far
# https://innopolis.university/antiterror/
# 101467 distinct word(s) so far
# https://innopolis.university/en/ido/?special=Y
# 101467 distinct word(s) so far
# https://innopolis.university/en/ido/#block5358
# 101467 distinct word(s) so far
# tel:+7 (843) 239-24-52
# 101467 distinct word(s) so far
# https://university.innopolis.ru/
# 101467 distinct word(s) so far
# https://dovuz.innopolis.university/informatika-i-programmirovanie/
# 101495 distinct word(s) so far
# https://dovuz.innopolis.university/informacionnaya-bezopasnost/
# 101527 distinct word(s) so far
# https://dovuz.innopolis.university/matematika/
# 101548 distinct word(s) so far
# https://dovuz.innopolis.university/proektnaya-deyatelnost/
# 101590 distinct word(s) so far
# https://dovuz.innopolis.university/robotics/
# 101619 distinct word(s) so far
# https://dovuz.innopolis.university/finansovye-tekhnologii/
# 101635 distinct word(s) so far
# https://dovuz.innopolis.university/news/
# 101650 distinct word(s) so far
# https://dovuz.innopolis.university/profile/
# 101650 distinct word(s) so far
# https://dovuz.innopolis.university/documents/
# 101673 distinct word(s) so far
# https://dovuz.innopolis.university/courses/
# 101703 distinct word(s) so far
# https://dovuz.innopolis.university/events/?archive=N&year=2021&season=summer
# 101703 distinct word(s) so far
# https://www.instagram.com/dovuziu/
# 101703 distinct word(s) so far
# https://www.facebook.com/dovuziu/
# 101703 distinct word(s) so far
# https://vk.com/dovuziu/
# 101812 distinct word(s) so far
# https://www.youtube.com/channel/UCedVh2M8ytTYDavSUTFWtAA/
# 101812 distinct word(s) so far
# https://dovuz.innopolis.university/ https:/t.me/dovuziu/
# 101812 distinct word(s) so far
# https://dovuz.innopolis.university/?archive=Y&year=2022
# 101814 distinct word(s) so far
# https://dovuz.innopolis.university/?archive=N&year=2022&season=winter
# 101814 distinct word(s) so far
# https://dovuz.innopolis.university/?archive=N&year=2022&season=spring
# 101815 distinct word(s) so far
# https://dovuz.innopolis.university/?archive=N&year=2022&season=summer
# 101815 distinct word(s) so far
# https://dovuz.innopolis.university/?archive=N&year=2022&season=autumn
# 101815 distinct word(s) so far
# https://dovuz.innopolis.university/events-calendar/
# 101815 distinct word(s) so far
# https://dovuz.innopolis.university/?archive=N&year=2022&season=winter&direction_id=213
# 101815 distinct word(s) so far
# https://dovuz.innopolis.university/?archive=N&year=2022&season=winter&direction_id=214
# 101815 distinct word(s) so far
# https://dovuz.innopolis.university/?archive=N&year=2022&season=winter&direction_id=215
# 101815 distinct word(s) so far
# https://dovuz.innopolis.university/?archive=N&year=2022&season=winter&direction_id=216
# 101815 distinct word(s) so far
# https://dovuz.innopolis.university/?archive=N&year=2022&season=winter&direction_id=217
# 101815 distinct word(s) so far
# https://dovuz.innopolis.university/?archive=N&year=2022&season=winter&direction_id=218
# 101815 distinct word(s) so far
# https://dovuz.innopolis.university/?archive=N&year=2022&season=winter&direction_id=255
# 101815 distinct word(s) so far
# https://dovuz.innopolis.university/ege-informatika/
# 101901 distinct word(s) so far
# https://dovuz.innopolis.university/ege-fizika/
# 101983 distinct word(s) so far
# https://dovuz.innopolis.university/ege-maths/
# 101999 distinct word(s) so far
# http://dovuz.innopolis.university/2d-game/?utm_source=site&utm_medium=news&utm_campaign=dovuz&utm_content=3feb
# 102051 distinct word(s) so far
# https://dovuz.innopolis.university/chatbot/?utm_source=site&utm_medium=news&utm_campaign=dovuz&utm_content=3feb
# 102061 distinct word(s) so far
# https://dovuz.innopolis.university/django/?utm_source=site&utm_medium=news&utm_campaign=dovuz&utm_content=3feb
# 102065 distinct word(s) so far
# https://dovuz.innopolis.university/prog-cpp/?utm_source=site&utm_medium=news&utm_campaign=dovuz&utm_content=3feb
# 102097 distinct word(s) so far
# https://dovuz.innopolis.university/intensiv-ege-matem/?utm_source=site&utm_medium=news&utm_campaign=dovuz&utm_content=3feb
# 102129 distinct word(s) so far
# https://dovuz.innopolis.university/intensiv-ege-informatika/?utm_source=site&utm_medium=news&utm_campaign=dovuz&utm_content=3feb
# 102134 distinct word(s) so far
# https://dovuz.innopolis.university/news/startoval-nabor-na-vesennie-intensivy-po-programmirovaniyu-i-podgotovke-k-ege/
# 102134 distinct word(s) so far
# https://dovuz.innopolis.university/news/vebinar-dlya-abiturientov-2022/
# 102150 distinct word(s) so far
# https://dovuz.innopolis.university/news/otkryta-registratsiya-na-kursy-po-programmirovaniyu-i-geometrii-/
# 102176 distinct word(s) so far
# https://dovuz.innopolis.university/tel:78432039253
# 102176 distinct word(s) so far
# http://dovuz.innopolis.university/about/
# 102176 distinct word(s) so far
# http://dovuz.innopolis.university/events/
# 102176 distinct word(s) so far
# http://dovuz.innopolis.university/news/
# 102176 distinct word(s) so far
# https://dovuz.innopolis.university/public/files/Согласие на обработку ПДн для УИ.pdf
# Skipping https://dovuz.innopolis.university/public/files/Согласие на обработку ПДн для УИ.pdf
# https://university.innopolis.ru/en/about/?special=Y
# 102176 distinct word(s) so far
# https://university.innopolis.ru/search/
# 102176 distinct word(s) so far
# https://university.innopolis.ru/about/
# 102176 distinct word(s) so far
# https://university.innopolis.ru/upload/iblock/c68/AR_2016.pdf
# Skipping https://university.innopolis.ru/upload/iblock/c68/AR_2016.pdf
# https://university.innopolis.ru/upload/iblock/26c/AR_2017.pdf
# Skipping https://university.innopolis.ru/upload/iblock/26c/AR_2017.pdf
# https://university.innopolis.ru/upload/iblock/59f/AR_2018.pdf
# Skipping https://university.innopolis.ru/upload/iblock/59f/AR_2018.pdf
# https://university.innopolis.ru/upload/iblock/0b2/AR_2019.pdf
# Skipping https://university.innopolis.ru/upload/iblock/0b2/AR_2019.pdf
# https://university.innopolis.ru/upload/iblock/189/AR2020(3).pdf
# Skipping https://university.innopolis.ru/upload/iblock/189/AR2020(3).pdf
# https://university.innopolis.ru/public/files/Consent_to_the_processing_of_PD_for_UI.pdf
# ...
# https://docs.google.com/document/d/1D23NYEsWNRexYgeYT8Om3oaNVyGealNYfqOaYlqV4xs/edit
# 102533 distinct word(s) so far
# http://www.campuslife.innopolis.ru/volunteering
# 102535 distinct word(s) so far
# http://www.campuslife.innopolis.ru/tutorship
# 102535 distinct word(s) so far
# http://www.campuslife.innopolis.ru/aboutsu
# 102548 distinct word(s) so far
# http://www.campuslife.innopolis.ru/studentreps
# 102564 distinct word(s) so far
# https://www.facebook.com/InnopolisStudents
# 102564 distinct word(s) so far
# https://vk.com/innostudents
# 102610 distinct word(s) so far
# https://www.instagram.com/innostudents/
# 102610 distinct word(s) so far
# http://t.me/StudentAffairs_bot
# 102614 distinct word(s) so far
# https://tilda.cc/?upm=686376
# 103123 distinct word(s) so far
# http://globalai.innopolis.university/
# 103155 distinct word(s) so far
# https://media.innopolis.university/news/grant-na-obuchenie-v-universitete-innopolis-detali-konkursnogo-otbora/
# 103213 distinct word(s) so far
# https://media.innopolis.university/news/blockchain-platform-iu/
# 103241 distinct word(s) so far
# https://media.innopolis.university/public/files/Согласие на обработку ПДн для УИ.pdf
# Skipping https://media.innopolis.university/public/files/Согласие на обработку ПДн для УИ.pdf
# https://us02web.zoom.us/j/9660990045?pwd=haAZQtiWaT-BVj-FamfQPy-KdnNBvQ
# 103241 distinct word(s) so far
# https://us02web.zoom.us/j/86924417470?pwd=cWpHUlk4OG5BcVNjek94Qk9mMEFjQT09
# 103241 distinct word(s) so far
# https://us02web.zoom.us/j/82115193290?pwd=aStDSVpXUnV5Q0JwZXB3Lys4YmJQUT09
# 103241 distinct word(s) so far
# https://us02web.zoom.us/j/81023939550?pwd=ZHZka0hGTVh4RWFoOUZ3V3lESjVYUT09
# 103241 distinct word(s) so far
# https://us02web.zoom.us/j/84204806112?pwd=Q0ROZkw3bmVGUTB2Q3pYRjFPRWk0UT09
# 103241 distinct word(s) so far
# https://media.innopolis.university/?TAGS=Наука
# 103352 distinct word(s) so far
# https://media.innopolis.university/?TAGS= Международное сотрудничество
# 103415 distinct word(s) so far
# https://cs.gssi.it/devops2020/
# 103475 distinct word(s) so far
# https://media.innopolis.university/news/Indie-GameDev-hack/
# 103516 distinct word(s) so far
# https://media.innopolis.university/news/davos-iu/
# 103549 distinct word(s) so far
# https://media.innopolis.university/news/digital-operating-room/
# 103643 distinct word(s) so far
# https://media.innopolis.university/news/opentalks-ai-2021/
# 103661 distinct word(s) so far
# https://media.innopolis.university/news/Hyperchaos-qubits/
# 103778 distinct word(s) so far
# http://apply.innopolis.ru/en/it-degree/
# 103778 distinct word(s) so far
# http://apply.innopolis.ru/en/get-in/guidelines/
# 103780 distinct word(s) so far
# https://pruffme.com/landing/u139557/applyDec24
# 103807 distinct word(s) so far
# https://media.innopolis.university/?TAGS=Школа
# 103855 distinct word(s) so far
# https://media.innopolis.university/?TAGS= Образование
# 103887 distinct word(s) so far
# https://olymp.innopolis.ru/ooui/
# 103963 distinct word(s) so far
# mailto:olymp@innopolis.ru
# 103963 distinct word(s) so far
# mailto:iu.ctf@innopolis.ru
# 103963 distinct word(s) so far
# https://media.innopolis.university/news/hramov-stroke/
# 104053 distinct word(s) so far
# https://media.innopolis.university/news/accepting-sibur-challenge/
# 104096 distinct word(s) so far
# https://media.innopolis.university/news/rucode-third-2021/
# 104118 distinct word(s) so far
# https://media.innopolis.university/news/wro-courses-2021/
# 104155 distinct word(s) so far
# https://media.innopolis.university/news/virtual-innopolis-open-robotics-2021/
# 104191 distinct word(s) so far
# https://www.riverpublishers.com/books.php
# 104796 distinct word(s) so far
# https://media.innopolis.university/news/visa-everywhere-initiative/
# 104866 distinct word(s) so far
# https://media.innopolis.university/news/data-fest-2019/
# 104886 distinct word(s) so far
# https://apply.innopolis.ru/en/master/
# 104886 distinct word(s) so far
# https://apply.innopolis.ru/en/it-degree/
# 104886 distinct word(s) so far
# https://apply.innopolis.ru/en/get-in/guidelines/
# 104886 distinct word(s) so far
# https://www.facebook.com/InnopolisU/
# 104886 distinct word(s) so far
# https://twitter.com/InnopolisU/status/974558530815500288
# 104894 distinct word(s) so far
# https://www.linkedin.com/company/innopolis-university/
# 104894 distinct word(s) so far
# mailto:admissions@Innopolis.ru
# 104894 distinct word(s) so far
# https://media.innopolis.university/en/?TAGS=*
# 104894 distinct word(s) so far
# https://media.innopolis.university/en/?TAGS=Industry
# 104894 distinct word(s) so far
# https://media.innopolis.university/en/?TAGS=Research
# 104894 distinct word(s) so far
# https://media.innopolis.university/en/?TAGS=Education
# 104894 distinct word(s) so far
# https://media.innopolis.university/en/?TAGS=Students life
# 104894 distinct word(s) so far
# https://media.innopolis.university/en/?TAGS=Global
# 104894 distinct word(s) so far
# https://media.innopolis.university/en/?TAGS=Robotics
# 104894 distinct word(s) so far
# https://media.innopolis.university/en/?TAGS=Blockchain
# 104894 distinct word(s) so far
# https://media.innopolis.university/en/?TAGS=Cybersecurity
# 104894 distinct word(s) so far
# https://vk.com/photo-56385969_457245707?rev=1&from=profile
# 104896 distinct word(s) so far
# https://vk.com/login?to=aW5ub3BvbGlzdQ--
# 104899 distinct word(s) so far
# https://vk.com/away.php?to=http%3A%2F%2Finnopolis.university
# 104899 distinct word(s) so far
# https://maps.google.com/?q=55.753352%2C48.743438
# 104901 distinct word(s) so far
# https://vk.com/attachments?act=attach_money&target=mail-56385969
# 104901 distinct word(s) so far
# https://vk.com/@innopolisu
# 104933 distinct word(s) so far
# https://vk.com/innopolisu?act=members
# 104933 distinct word(s) so far
# https://vk.com/innopolisu?menu_opened#menu
# 104933 distinct word(s) so far
# https://vk.com/albums-56385969
# 104938 distinct word(s) so far
# https://vk.com/board56385969
# 104955 distinct word(s) so far
# https://vk.com/videos-56385969
# 104956 distinct word(s) so far
# https://vk.com/innopolisu?act=links
# 104956 distinct word(s) so far
# https://vk.com/innopolisu?act=contacts
# 104956 distinct word(s) so far
# https://vk.com/wall?act=toggle_subscribe&owner_id=-56385969&subscribe=1&from=group&hash=2eb45b830255f6a59f
# 104956 distinct word(s) so far
# https://vk.com/fave?act=add_group&reference=profile&gid=56385969&hash=1599237a0aba4dd166
# 104956 distinct word(s) so far
# https://vk.com/innopolisu?search=1
# 104956 distinct word(s) so far
# https://vk.com/reports?act=add_community&group_id=56385969&hash=e2203649b6fa3ebea1
# 104956 distinct word(s) so far
# https://vk.com/innopolisu?own=0#wall
# 104956 distinct word(s) so far
# https://vk.com/innopolisu?own=1#wall
# 104956 distinct word(s) so far
# https://vk.com/innopolisu?from=group
# 104956 distinct word(s) so far
# https://vk.com/wall-56385969_11035
# 104957 distinct word(s) so far
# https://vk.com/photo-56385969_457246011?rev=1&post=-56385969_11035&from=group
# 104994 distinct word(s) so far
# https://vk.com/innopolisu?reactions_opened=wall-56385969_11035#wall-56385969_11035-reaction
# 104994 distinct word(s) so far
# https://vk.com/like?act=publish&object=wall-56385969_11035&from=innopolisu&post_bottom=1
# 104994 distinct word(s) so far
# https://vk.com/wall-56385969_11031
# 105003 distinct word(s) so far
# https://vk.com/away.php?to=https%3A%2F%2Fmedia.innopolis.university%2Fnews%2Fvesennie-intensivy-iu-2022%2F&post=-56385969_11031
# 105003 distinct word(s) so far
# https://vk.com/photo-56385969_457246010?rev=1&post=-56385969_11031&from=group
# 105003 distinct word(s) so far
# https://vk.com/innopolisu?reactions_opened=wall-56385969_11031#wall-56385969_11031-reaction
# 105003 distinct word(s) so far
# https://vk.com/like?act=publish&object=wall-56385969_11031&from=innopolisu&post_bottom=1
# 105003 distinct word(s) so far
# https://vk.com/wall-56385969_11029
# 105003 distinct word(s) so far
# https://vk.com/careersber?from=group
# 105101 distinct word(s) so far
# https://vk.com/wall-163984940_11180
# 105114 distinct word(s) so far
# https://vk.com/video-163984940_456239916?list=06d1b7d2e8739524e6&from=wall-56385969_11029
# 105116 distinct word(s) so far
# https://vk.com/innopolisu?reactions_opened=wall-56385969_11029#wall-56385969_11029-reaction
# 105116 distinct word(s) so far
# https://vk.com/like?act=publish&object=wall-56385969_11029&from=innopolisu&post_bottom=1
# 105116 distinct word(s) so far
# https://vk.com/wall-56385969_11027
# 105116 distinct word(s) so far
# https://vk.com/away.php?to=https%3A%2F%2Fwww.comnews.ru%2Fdigital-economy%2Fcontent%2F218591%2F2022-02-01%2F2022-w05%2Ftatneft-i-universitet-innopolis-cifroviziruyut-monitoring-razrabotki-mestorozhdeniy&post=-56385969_11027
# 105116 distinct word(s) so far
# https://vk.com/tatneft_official
# 105228 distinct word(s) so far
# https://vk.com/photo-56385969_457246009?rev=1&post=-56385969_11027&from=group
# 105228 distinct word(s) so far
# https://vk.com/innopolisu?reactions_opened=wall-56385969_11027#wall-56385969_11027-reaction
# 105228 distinct word(s) so far
# https://vk.com/like?act=publish&object=wall-56385969_11027&from=innopolisu&post_bottom=1
# 105228 distinct word(s) so far
# https://vk.com/wall-56385969_11024
# 105228 distinct word(s) so far
# https://vk.com/away.php?to=https%3A%2F%2Fteam-project.university.innopolis.ru%2Folymp-robotics&post=-56385969_11024
# 105228 distinct word(s) so far
# https://vk.com/photo-56385969_457246008?rev=1&post=-56385969_11024&from=group
# 105228 distinct word(s) so far
# https://vk.com/innopolisu?reactions_opened=wall-56385969_11024#wall-56385969_11024-reaction
# 105228 distinct word(s) so far
# https://vk.com/like?act=publish&object=wall-56385969_11024&from=innopolisu&post_bottom=1
# 105228 distinct word(s) so far
# https://vk.com/innopolisu?offset=5&own=1
# 105228 distinct word(s) so far
# https://www.youtube.com/
# 105228 distinct word(s) so far
# https://www.youtube.com/about/
# 105239 distinct word(s) so far
# https://www.youtube.com/about/press/
# 105290 distinct word(s) so far
# https://www.youtube.com/about/copyright/
# 105885 distinct word(s) so far
# https://www.youtube.com/t/contact_us/
# 105939 distinct word(s) so far
# https://www.youtube.com/creators/
# 106071 distinct word(s) so far
# https://www.youtube.com/ads/
# 106391 distinct word(s) so far
# https://developers.google.com/youtube
# 106437 distinct word(s) so far
# https://www.youtube.com/t/terms
# 107089 distinct word(s) so far
# https://www.youtube.com/t/privacy
# 108092 distinct word(s) so far
# https://www.youtube.com/about/policies/
# 108360 distinct word(s) so far
# https://www.youtube.com/howyoutubeworks?utm_campaign=ytgen&utm_source=ythp&utm_medium=LeftNav&utm_content=txt&u=https%3A%2F%2Fwww.youtube.com%2Fhowyoutubeworks%3Futm_source%3Dythp%26utm_medium%3DLeftNav%26utm_campaign%3Dytgen
# 108454 distinct word(s) so far
# https://www.youtube.com/new
# 108454 distinct word(s) so far
# https://apply.innopolis.ru/?special=Y
# 108454 distinct word(s) so far
# https://apply.innopolis.ru/en/
# 108454 distinct word(s) so far
# http://innopolis.ru/city/
# 108518 distinct word(s) so far
# https://apply.innopolis.ru/non-grant/
# 108531 distinct word(s) so far
# https://media.innopolis.university/news/startoval-nabor-na-vesennie-intensivy-po-programmirovaniyu-i-podgotovke-k-ege/
# 108531 distinct word(s) so far
# https://media.innopolis.university/news/vebinar-dlya-abiturientov-2022/
# 108531 distinct word(s) so far
# https://apply.innopolis.ru/public/files/Согласие на обработку ПДн для УИ.pdf
# Skipping https://apply.innopolis.ru/public/files/Согласие на обработку ПДн для УИ.pdf
# https://www.facebook.com/AdmissionIU
# 108531 distinct word(s) so far
# https://vk.com/innopolisadmissions
# 108687 distinct word(s) so far
# https://www.instagram.com/admissions_iu/
# 108687 distinct word(s) so far
# https://iustore.innopolis.ru/
# 108687 distinct word(s) so far
# tel:+7 (843) 203-92-53
# 108687 distinct word(s) so far
# https://innopolis.com/city/how-to-get/
# 108687 distinct word(s) so far
# https://minobrnauki.gov.ru/
# 108687 distinct word(s) so far
# https://university.innopolis.ru/en/
# 108687 distinct word(s) so far
# https://media.innopolis.university/en/news/?TAGS=*
# 108687 distinct word(s) so far
# https://media.innopolis.university/en/news/?TAGS=Industry
# 108687 distinct word(s) so far
# https://media.innopolis.university/en/news/?TAGS=Research
# 108687 distinct word(s) so far
# https://media.innopolis.university/en/news/?TAGS=Education
# 108687 distinct word(s) so far
# https://media.innopolis.university/en/news/?TAGS=Students life
# 108687 distinct word(s) so far
# https://media.innopolis.university/en/news/?TAGS=Global
# 108687 distinct word(s) so far
# https://media.innopolis.university/en/news/?TAGS=Robotics
# 108687 distinct word(s) so far
# https://media.innopolis.university/en/news/?TAGS=Blockchain
# 108687 distinct word(s) so far
# https://media.innopolis.university/en/news/?TAGS=Cybersecurity
# 108687 distinct word(s) so far
# https://media.innopolis.university/en/news/?PAGEN_2=2
# 108687 distinct word(s) so far
# https://media.innopolis.university/en/news/?PAGEN_2=3
# 108687 distinct word(s) so far
# https://media.innopolis.university/en/news/?PAGEN_2=38
# 108687 distinct word(s) so far
# https://media.innopolis.university/en/news/?PAGEN_2=39
# 108687 distinct word(s) so far
# https://media.innopolis.university/en/events/?date=
# 108687 distinct word(s) so far
# https://media.innopolis.university/en/events/?date=past
# 108687 distinct word(s) so far
# https://media.innopolis.university/en/events/?SECTION_ID=
# 108687 distinct word(s) so far
# http://www.minsvyaz.ru/
# 108687 distinct word(s) so far
# http://www.minsvyaz.ru/en/ministry/common/
# 108749 distinct word(s) so far
# http://www.minsvyaz.ru/en/events/list/
# 108840 distinct word(s) so far
# http://www.minsvyaz.ru/en/activity/
# 108840 distinct word(s) so far
# http://www.minsvyaz.ru/en/documents/
# 108840 distinct word(s) so far
# http://www.minsvyaz.ru/en/contacts/
# 108876 distinct word(s) so far
# http://www.minsvyaz.ru/set_lang/ru/
# 108876 distinct word(s) so far
# http://www.minsvyaz.ru/en/None
# 108878 distinct word(s) so far
# http://www.minsvyaz.ru/en/events/40758/
# 108894 distinct word(s) so far
# http://www.minsvyaz.ru/en/events/34346/
# 108915 distinct word(s) so far
# http://www.minsvyaz.ru/en/events/34343/
# 108926 distinct word(s) so far
# http://www.minsvyaz.ru/en/events/34340/
# 108936 distinct word(s) so far
# http://www.minsvyaz.ru/en/events/34334/
# 108970 distinct word(s) so far
# http://www.minsvyaz.ru/en/ministry/structure/
# 108995 distinct word(s) so far
# http://www.minsvyaz.ru/en/contacts/media/
# 109000 distinct word(s) so far
# https://twitter.com/mintsifry
# 109000 distinct word(s) so far
# https://www.facebook.com/mintsifry?fref=ts
# 109000 distinct word(s) so far
# https://www.instagram.com/mintsifry
# 109000 distinct word(s) so far
# https://t.co/PvattmYTVF
# 109000 distinct word(s) so far
# https://t.co/3Qc4MHFr2O
# 109000 distinct word(s) so far
# http://twitter.com/MedvedevRussiaE
# 109000 distinct word(s) so far
# https://twitter.com/telegram:
# 109000 distinct word(s) so far
# https://t.co/69Yhn2MCrK
# 109002 distinct word(s) so far
# http://twitter.com/nnikiforov
# 109002 distinct word(s) so far
# http://twitter.com/@mission_russian
# 109002 distinct word(s) so far
# https://twitter.com/hashtag/Russia
# 109002 distinct word(s) so far
# https://twitter.com/hashtag/Iran
# 109002 distinct word(s) so far
# https://t.co/3WeEJ8C11x
# 109263 distinct word(s) so far
# http://twitter.com/SteppeDispatch
# 109263 distinct word(s) so far
# http://www.minsvyaz.ru/en/contacts/letter/
# 109265 distinct word(s) so far
# http://www.minsvyaz.ru/en/search/
# 109266 distinct word(s) so far
# http://www.minsvyaz.ru/en/subscription/#rss
# 109266 distinct word(s) so far
# http://www.minsvyaz.ru/opendata/
# 109338 distinct word(s) so far
# http://www.minsvyaz.ru/en/subscription/
# 109338 distinct word(s) so far
# http://www.minsvyaz.ru/en/pages/about/
# 109344 distinct word(s) so far
# https://cnt.sputnik.ru/report/894092
# 109344 distinct word(s) so far
# Done
# [('university', 3205), ('иннополис', 2957), ('университета', 2186), ('innopolis', 2011), ('with', 1710), ('research', 1630), ('science', 1405), ('университет', 1402), ('this', 1380), ('development', 1284), ('software', 1264), ('лаборатория', 1230), ('data', 1220), ('students', 1195), ('youtube', 1176), ('центр', 1139), ('education', 1109), ('университете', 1074), ('данных', 1066), ('области', 1050)]
